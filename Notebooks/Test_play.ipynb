# %%
from scipy import integrate
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import operator
sns.set(rc={'figure.figsize':(12,8)})
# %matplotlib inline
plt.style.use('default')

# %%
y = [(np.exp(-2*x)) for x in np.linspace(0, 1, num=50)]
x = np.linspace(0, 1 , num=50)
plt.plot(x[1:], y[1:] , 'r--')
y_int = integrate.cumtrapz(y, x)
plt.plot(x[1:], y_int , 'b--')
plt.show()

# %%
y_int
# Out:
# array([0.02000006, 0.03920022, 0.05763248, 0.07532755, 0.09231491,
#        0.10862287, 0.1242786 , 0.13930819, 0.15373668, 0.1675881 ,
#        0.18088555, 0.19365116, 0.20590623, 0.21767115, 0.22896555,
#        0.23980823, 0.25021726, 0.26020998, 0.26980306, 0.27901246,
#        0.28785353, 0.29634101, 0.30448904, 0.31231119, 0.3198205 ,
#        0.32702948, 0.33395013, 0.340594  , 0.34697215, 0.3530952 ,
#        0.35897337, 0.36461645, 0.37003383, 0.37523454, 0.38022726,
#        0.38502029, 0.38962163, 0.39403894, 0.39827959, 0.40235062,
#        0.40625884, 0.41001076, 0.41361261, 0.41707041, 0.42038992,
#        0.42357667, 0.42663596, 0.4295729 , 0.43239238])
