# %%
import geopandas as gpd
import pandas as pd

# %%
walkability = gpd.read_file('../Data/shapes/Central_London_Walkability_Polylines_Buffered_45m.shp')

# %%
walkability.head()
# Out:
#    content_id                name Overall RoadSafety EasyCross Pavement  \
# 0     34239.0     Marylebone Road  2.1875        0.5       0.5      2.5
# 1     34248.0  Marylebone Flyover  2.0625        0.5       0.5      2.5
# 2     34264.0     Marylebone Road  2.3125        0.5       0.5      2.5
# 3     34267.0      Sussex Gardens    1.75        0.5       0.5      2.5
# 4     34292.0     Marylebone Road  2.3125        0.5       0.5      2.5
#
#   Hilliness Navigation FearCrime SmartBeau FunRelax  Overall_re  id  \
# 0       1.5          4         3         4      1.5      2.1875   1
# 1         2          4       1.5         4      1.5      2.0625   1
# 2       2.5          4         3         4      1.5      2.3125   1
# 3       2.5        2.5         1         3      1.5      1.7500   1
# 4       3.5        2.5         3       4.5      1.5      2.3125   1
#
#    SmartBe_re  FunRelax_r  unique_id  \
# 0         4.0         1.5          1
# 1         4.0         1.5          2
# ...

# %%
walkability.plot()
