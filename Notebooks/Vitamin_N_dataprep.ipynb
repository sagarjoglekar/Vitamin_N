# %%
import geopandas as gpd
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
green_gpd = gpd.read_file("Choice_Green_scores/London_choice_green_scores.shp")

# %%
green_gpd.head(n=5)
# Out:
#     GSS_CODE            NAME  green_gsv  green_gsv_  green_gs_1  mean_choic  \
# 0  E05000026           Abbey  10.524896   10.687261   10.687261   14.176203
# 1  E05000027          Alibon  10.102674   10.269987   10.269987    9.614580
# 2  E05000028       Becontree  10.891959   11.220406   11.220406   12.623284
# 3  E05000029  Chadwell Heath  16.489458   16.415619   16.415619    8.776464
# 4  E05000030       Eastbrook   9.190002    9.635628    9.635628    7.141968
#
#    median_cho  std_choice  green_gs_2  area_sqkm  ...  ward_area  percent_on  \
# 0   13.855123    5.704466   68.095426    1.28292  ...  1282920.0    0.036192
# 1    8.563932    4.634217   70.179522    1.36442  ...  1364420.0    0.043492
# 2   13.285051    6.332820   89.797771    1.28809  ...  1288090.0    0.059345
# 3    9.297543    5.033655  108.994082    3.38422  ...  3384220.0    0.022585
# 4    7.007301    5.072869   38.705019    3.45060  ...  3450600.0    0.013875
#
# ...

# %%
green_gpd.columns
# Out:
# Index(['GSS_CODE', 'NAME', 'green_gsv', 'green_gsv_', 'green_gs_1',
#        'mean_choic', 'median_cho', 'std_choice', 'green_gs_2', 'area_sqkm',
#        'ward_green', 'gsv_tree_s', 'green_gs_3', 'green_gs_4', 'green_gs_5',
#        'green_gs_6', 'green_gs_7', 'green_sat', 'green_sat_', 'green_sa_1',
#        'green_sa_2', 'ward_sat_g', 'ward_code', 'ward_area', 'percent_on',
#        'percent_to', 'sat_all_wa', 'green_area', 'sat_ward_g', 'on_vs_off_',
#        'on_vs_of_1', 'sat_all__1', 'geometry'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20,20)
ax.axis('off')
ax.set_title('Off-road greenery', fontdict={'fontsize': '25', 'fontweight' : '500'})
sm = plt.cm.ScalarMappable(cmap='GnBu', norm=plt.Normalize(vmin=green_gpd['green_gsv_'].min(), vmax=green_gpd['green_gsv_'].max()))
#empty array for the data range
sm._A = []
#add the colorbar to the figure
cbar = fig.colorbar(sm,shrink=0.3)
for t in cbar.ax.get_yticklabels():
     t.set_fontsize(25)
green_gpd.plot(ax=ax,column='green_gsv_', cmap='GnBu', linewidth=0.8)
